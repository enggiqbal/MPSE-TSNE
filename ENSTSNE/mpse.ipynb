# %%
import numpy as np 
from new_enstsne import load_penguins, load_clusters
from eval import vis_3d, vis_2d
import mview

# %%
dists, labels, X = load_clusters(400,[10,10,10], [4,3,2])

# %%
mpse = mview.basic(dists)
vis_3d(mpse.embedding,labels)
# Out:
# (400, 400)
# (400, 400)
# (400, 400)
# len 1
# len 1
# len 1
# len 1

# %%
vis_2d(mpse.images, labels)

# %%
one = np.loadtxt("datasets/123/1.txt", delimiter=",")
two = np.loadtxt("datasets/123/2.txt", delimiter=",")
three = np.loadtxt("datasets/123/3.txt", delimiter=",")
dists = [one,two,three]

# %%
# mpse = mview.basic(dists)

# %%
from new_enstsne import ENSTSNE
enstsne = ENSTSNE(dists,30)
hist = enstsne.gd(5000)

enstsne.vis_2d()
# Out:
# 0.01
# 100%|██████████| 5000/5000 [01:25<00:00, 58.70it/s]
# (250, 3) (2, 3)
# (250, 3) (2, 3)
# (250, 3) (2, 3)

# %%
import pylab as plt
plt.plot(range(len(hist)-1), hist[1:])
