# %% [markdown]
# This notebook contains examples on how to easily use mview to run mpse-tsne.This is accomplished using the function mview.mpse_tsne, which is optimized to use mview.MPSE for solving mpse-tsne problems.

# %%
import sys
sys.path.insert(0,"../")
import mview

import numpy as np
import random
import matplotlib.pyplot as plt

# %% [markdown]
# By default, mpse_tsne solves the mpse-tsne problem with variable projections, using a combination of gradient descent schemes (full gradient with fixed projections, batch gradient w/ multiple batch sizes, full gradient with adaptive and fixed rates).
#
# The only required argument is the data describing the distances. In the next few examples I'll show how to run the examples that have already been incorporated into the module, in which case a single string is necessary. In the file 'mpse_tsne_running.ipynb' I'll describe how to run the code for data not already incorporated into the module.
#
# In addition to the dataset name (the only argument of mview.mpse_tsne, other variables that help describe the data can be added too (for examples, the number of samples to use is n_samples). Some variables only affect a particular dataset, but there is no danger in adding a variable that is not applicable.
#
# The saved datasets so far are 'equidistant', 'disk', 'clusters', 'clusters2', '123', 'florence', 'credit', 'phishing', and 'mnist'.
#
# Below is the 3-perspective, 2-cluster example. The dataset name is 'clusters'. You can specify the number of clusters and number of perspectives as shown below.

# %%
mview.mpse_tsne('clusters', n_samples=500, n_clusters=2, n_perspectives=3, perplexity=200,
               show_plots=True, verbose=2)
# Out:
#   mview.MPSE():
#     data details:
#       number of perspectives : 3
#       number of samples : 500
#     visualization details:
#       embedding dimension : 3
#       image dimension : 2
#       visualization type : tsne
#   setup visualization instance for perspective 1 :
#       mview.TSNE():
#         data details:
#           number of samples : 500
#         embedding details:
#           embedding dimension : 2
#           perplexity : 200.00
#         TSNE.initialize():
#           method : random
#           initial cost : 1.97e+00
#   setup visualization instance for perspective 2 :
#       mview.TSNE():
#         data details:
#           number of samples : 500
#         embedding details:
#           embedding dimension : 2
#           perplexity : 200.00
#         TSNE.initialize():
#           method : random
#           initial cost : 1.97e+00
#   setup visualization instance for perspective 3 :
#       mview.TSNE():
#         data details:
#           number of samples : 500
#         embedding details:
#           embedding dimension : 2
#           perplexity : 200.00
#         TSNE.initialize():
#           method : random
#           initial cost : 1.98e+00
#     initialize:
#       fixed embedding : False
#       initial embedding : random
#       fixed projections : False
#       initial projections : random
#     MPSE.gd():
#         initial stress : 1.94e+00
#         mpse method : fixed projections
#       gd.single():
#         computation parameters:
#           stochastic : False
#           constraint : False
#           scheme : bb
#           initial lr : 1.00e+02
#           max_iter : 10
#           max_step : 1.00e+10
#         progress:
#           iter:      cost:     grad:     lr:       step:
#             10/  10  1.51e+00  4.24e-04  3.70e+02  9.99e-02
#         results:
#           conclusion : maximum number of iterations reached
#           total iterations : 10
#           final cost : 1.51e+00
#           final gradient size : 4.24e-04
#           final learning rate : 3.70e+02
#           final step size : 9.99e-02
#           time : 1.75e-01 [sec]
#       final cost : 1.45
#       individual costs : 1.19, 1.87, 1.17
#     MPSE.gd():
#         initial stress : 1.45e+00
#         fixed : None
#         batch size : 100
#       gd.multiple():
#         computation parameters:
#           stochastic : True
#           constraint : True
#           projected : [False, True]
#           scheme : ['mm', 'mm']
#           initial lr : 1.00e+02, 1.00e+01
#           max_iter : 10
#           max_step : 1.00e+10
#         progress:
#           iter:      cost:     grad:     lr:       step:
#             10/  10  1.38e+00  3.03e-01  8.94e+00  6.35e-01
#         results:
#           conclusion : maximum number of iterations reached
#           total iterations : 10
#           final cost : 1.38e+00
#           time : 7.43e-01 [sec]
#       final cost : 1.40
#       individual costs : 1.23, 1.72, 1.20
#     MPSE.gd():
#         initial stress : 1.40e+00
#         fixed : None
#         batch size : 50
#       gd.multiple():
#         computation parameters:
#           stochastic : True
#           constraint : True
#           projected : [False, True]
#           scheme : ['mm', 'mm']
#           initial lr : 1.00e+02, 1.00e+01
#           max_iter : 10
#           max_step : 1.00e+10
#         progress:
#           iter:      cost:     grad:     lr:       step:
#             10/  10  1.29e+00  3.40e-01  1.86e+01  7.38e-01
#         results:
#           conclusion : maximum number of iterations reached
#           total iterations : 10
#           final cost : 1.29e+00
#           time : 4.40e-01 [sec]
#       final cost : 1.39
#       individual costs : 1.33, 1.48, 1.36
#     MPSE.gd():
#         initial stress : 1.39e+00
#         fixed : None
#       gd.multiple():
#         computation parameters:
#           stochastic : False
#           constraint : True
#           projected : [False, True]
#           scheme : ['bb', 'bb']
#           initial lr : 1.00e+02, 1.00e+01
#           max_iter : 100
#           max_step : 1.00e+10
#         progress:
#           iter:      cost:     grad:     lr:       step:
#            100/ 100  1.28e+00  2.99e-01  1.74e-01  3.49e-01
#         results:
#           conclusion : maximum number of iterations reached
#           total iterations : 100
#           final cost : 1.28e+00
#           time : 3.21e+00 [sec]
#       final cost : 1.27
#       individual costs : 1.75, 0.98, 0.91

# %% [markdown]
# The same cluster example using a different configuration is shown below.

# %%
mview.mpse_tsne('clusters', n_samples=500, n_clusters=[3,4,2], perplexity=100,
               show_plots=True, verbose=2)
# Out:
#   mview.MPSE():
#     data details:
#       number of perspectives : 3
#       number of samples : 500
#     visualization details:
#       embedding dimension : 3
#       image dimension : 2
#       visualization type : tsne
#   setup visualization instance for perspective 1 :
#       mview.TSNE():
#         data details:
#           number of samples : 500
#         embedding details:
#           embedding dimension : 2
#           perplexity : 100.00
#         TSNE.initialize():
#           method : random
#           initial cost : 3.35e+00
#   setup visualization instance for perspective 2 :
#       mview.TSNE():
#         data details:
#           number of samples : 500
#         embedding details:
#           embedding dimension : 2
#           perplexity : 100.00
#         TSNE.initialize():
#           method : random
#           initial cost : 3.36e+00
#   setup visualization instance for perspective 3 :
#       mview.TSNE():
#         data details:
#           number of samples : 500
#         embedding details:
#           embedding dimension : 2
#           perplexity : 100.00
#         TSNE.initialize():
#           method : random
#           initial cost : 3.36e+00
#     initialize:
#       fixed embedding : False
#       initial embedding : random
#       fixed projections : False
#       initial projections : random
#     MPSE.gd():
#         initial stress : 3.32e+00
#         mpse method : fixed projections
#       gd.single():
#         computation parameters:
#           stochastic : False
#           constraint : False
#           scheme : bb
#           initial lr : 1.00e+02
#           max_iter : 10
#           max_step : 1.00e+10
#         progress:
#           iter:      cost:     grad:     lr:       step:
#             10/  10  3.00e+00  4.69e-04  2.65e+01  5.06e-03
#         results:
#           conclusion : maximum number of iterations reached
#           total iterations : 10
#           final cost : 3.00e+00
#           final gradient size : 4.69e-04
#           final learning rate : 2.65e+01
#           final step size : 5.06e-03
#           time : 1.88e-01 [sec]
#       final cost : 2.99
#       individual costs : 3.04, 2.95, 2.99
#     MPSE.gd():
#         initial stress : 2.99e+00
#         fixed : None
#         batch size : 100
#       gd.multiple():
#         computation parameters:
#           stochastic : True
#           constraint : True
#           projected : [False, True]
#           scheme : ['mm', 'mm']
#           initial lr : 1.00e+02, 1.00e+01
#           max_iter : 10
#           max_step : 1.00e+10
#         progress:
#           iter:      cost:     grad:     lr:       step:
#             10/  10  2.82e+00  1.70e-01  7.51e+00  6.40e-01
#         results:
#           conclusion : maximum number of iterations reached
#           total iterations : 10
#           final cost : 2.82e+00
#           time : 7.04e-01 [sec]
#       final cost : 2.85
#       individual costs : 2.92, 2.75, 2.87
#     MPSE.gd():
#         initial stress : 2.85e+00
#         fixed : None
#         batch size : 50
#       gd.multiple():
#         computation parameters:
#           stochastic : True
#           constraint : True
#           projected : [False, True]
#           scheme : ['mm', 'mm']
#           initial lr : 1.00e+02, 1.00e+01
#           max_iter : 10
#           max_step : 1.00e+10
#         progress:
#           iter:      cost:     grad:     lr:       step:
#             10/  10  2.82e+00  2.93e-01  7.51e+00  1.00e+00
#         results:
#           conclusion : maximum number of iterations reached
#           total iterations : 10
#           final cost : 2.82e+00
#           time : 4.23e-01 [sec]
#       final cost : 2.84
#       individual costs : 2.90, 2.78, 2.83
#     MPSE.gd():
#         initial stress : 2.84e+00
#         fixed : None
#       gd.multiple():
#         computation parameters:
#           stochastic : False
#           constraint : True
#           projected : [False, True]
#           scheme : ['bb', 'bb']
#           initial lr : 1.00e+02, 1.00e+01
#           max_iter : 100
#           max_step : 1.00e+10
#         progress:
#           iter:      cost:     grad:     lr:       step:
#            100/ 100  2.36e+00  3.86e-01  1.13e+00  2.83e-02
#         results:
#           conclusion : maximum number of iterations reached
#           total iterations : 100
#           final cost : 2.36e+00
#           time : 3.38e+00 [sec]
#       final cost : 2.35
#       individual costs : 3.14, 0.85, 2.44

# %% [markdown]
# Here is mnist, which has name 'mnist'. We can only specify the number of samples here.

# %%
mview.mpse_tsne('mnist', n_samples=500, perplexity=30,
               show_plots=True, verbose=2)
# Out:
#   mview.MPSE():
#     data details:
#       number of perspectives : 2
#       number of samples : 1000
#     visualization details:
#       embedding dimension : 3
#       image dimension : 2
#       visualization type : tsne
#   setup visualization instance for perspective 1 :
#       mview.TSNE():
#         data details:
#           number of samples : 1000
#         embedding details:
#           embedding dimension : 2
#           perplexity : 30.00
#         TSNE.initialize():
#           method : random
#           initial cost : 6.85e+00
#   setup visualization instance for perspective 2 :
#       mview.TSNE():
#         data details:
#           number of samples : 1000
#         embedding details:
#           embedding dimension : 2
#           perplexity : 30.00
#         TSNE.initialize():
#           method : random
#           initial cost : 6.87e+00
#     initialize:
#       fixed embedding : False
#       initial embedding : random
#       fixed projections : False
#       initial projections : random
#     MPSE.gd():
#         initial stress : 6.83e+00
#         mpse method : fixed projections
#       gd.single():
#         computation parameters:
#           stochastic : False
#           constraint : False
#           scheme : bb
#           initial lr : 1.00e+02
#           max_iter : 10
#           max_step : 1.00e+10
#         progress:
#           iter:      cost:     grad:     lr:       step:
#             10/  10  6.04e+00  5.26e-04  2.79e+01  2.29e-02
#         results:
#           conclusion : maximum number of iterations reached
#           total iterations : 10
#           final cost : 6.04e+00
#           final gradient size : 5.26e-04
#           final learning rate : 2.79e+01
#           final step size : 2.29e-02
#           time : 3.22e-01 [sec]
#       final cost : 6.02
#       individual costs : 6.02, 6.02
#     MPSE.gd():
#         initial stress : 6.02e+00
#         fixed : None
#         batch size : 100
#       gd.multiple():
#         computation parameters:
#           stochastic : True
#           constraint : True
#           projected : [False, True]
#           scheme : ['mm', 'mm']
#           initial lr : 1.00e+02, 1.00e+01
#           max_iter : 10
#           max_step : 1.00e+10
#         progress:
#           iter:      cost:     grad:     lr:       step:
#             10/  10  6.02e+00  2.09e-01  1.09e+01  2.27e+00
#         results:
#           conclusion : maximum number of iterations reached
#           total iterations : 10
#           final cost : 6.02e+00
#           time : 9.59e-01 [sec]
#       final cost : 5.75
#       individual costs : 5.74, 5.75
#     MPSE.gd():
#         initial stress : 5.75e+00
#         fixed : None
#         batch size : 50
#       gd.multiple():
#         computation parameters:
#           stochastic : True
#           constraint : True
#           projected : [False, True]
#           scheme : ['mm', 'mm']
#           initial lr : 1.00e+02, 1.00e+01
#           max_iter : 10
#           max_step : 1.00e+10
#         progress:
#           iter:      cost:     grad:     lr:       step:
#             10/  10  5.59e+00  2.16e-01  1.03e+01  2.23e+00
#         results:
#           conclusion : maximum number of iterations reached
#           total iterations : 10
#           final cost : 5.59e+00
#           time : 5.78e-01 [sec]
#       final cost : 5.56
#       individual costs : 5.56, 5.56
#     MPSE.gd():
#         initial stress : 5.56e+00
#         fixed : None
#       gd.multiple():
#         computation parameters:
#           stochastic : False
#           constraint : True
#           projected : [False, True]
#           scheme : ['bb', 'bb']
#           initial lr : 1.00e+02, 1.00e+01
#           max_iter : 100
#           max_step : 1.00e+10
#         progress:
#           iter:      cost:     grad:     lr:       step:
#            100/ 100  4.44e+00  3.87e-01  2.05e+00  2.83e+00
#         results:
#           conclusion : maximum number of iterations reached
#           total iterations : 100
#           final cost : 4.44e+00
#           time : 6.64e+00 [sec]
#       final cost : 4.37
#       individual costs : 4.39, 4.36

# %% [markdown]
# Here we show the 123 example, with name '123'

# %%
mview.mpse_tsne('123', perplexity=300,
               show_plots=True, verbose=2)
# Out:
#   mview.MPSE():
#     data details:
#       number of perspectives : 3
#       number of samples : 1000
#     visualization details:
#       embedding dimension : 3
#       image dimension : 2
#       visualization type : tsne
#   setup visualization instance for perspective 1 :
#       mview.TSNE():
#         data details:
#           number of samples : 1000
#         embedding details:
#           embedding dimension : 2
#           perplexity : 300.00
#         TSNE.initialize():
#           method : random
#           initial cost : 2.50e+00
#   setup visualization instance for perspective 2 :
#       mview.TSNE():
#         data details:
#           number of samples : 1000
#         embedding details:
#           embedding dimension : 2
#           perplexity : 300.00
#         TSNE.initialize():
#           method : random
#           initial cost : 2.50e+00
#   setup visualization instance for perspective 3 :
#       mview.TSNE():
#         data details:
#           number of samples : 1000
#         embedding details:
#           embedding dimension : 2
#           perplexity : 300.00
#         TSNE.initialize():
#           method : random
#           initial cost : 2.51e+00
#     initialize:
#       fixed embedding : False
#       initial embedding : random
#       fixed projections : False
#       initial projections : random
#     MPSE.gd():
#         initial stress : 2.47e+00
#         mpse method : fixed projections
#       gd.single():
#         computation parameters:
#           stochastic : False
#           constraint : False
#           scheme : bb
#           initial lr : 1.00e+02
#           max_iter : 10
#           max_step : 1.00e+10
#         progress:
#           iter:      cost:     grad:     lr:       step:
#             10/  10  9.12e-01  1.88e-04  4.83e+02  7.62e-02
#         results:
#           conclusion : maximum number of iterations reached
#           total iterations : 10
#           final cost : 9.12e-01
#           final gradient size : 1.88e-04
#           final learning rate : 4.83e+02
#           final step size : 7.62e-02
#           time : 4.94e-01 [sec]
#       final cost : 0.86
#       individual costs : 0.74, 0.97, 0.86
#     MPSE.gd():
#         initial stress : 8.62e-01
#         fixed : None
#         batch size : 100
#       gd.multiple():
#         computation parameters:
#           stochastic : True
#           constraint : True
#           projected : [False, True]
#           scheme : ['mm', 'mm']
#           initial lr : 1.00e+02, 1.00e+01
#           max_iter : 10
#           max_step : 1.00e+10
#         progress:
#           iter:      cost:     grad:     lr:       step:
#             10/  10  7.70e-01  1.70e-01  1.22e+01  4.07e-01
#         results:
#           conclusion : maximum number of iterations reached
#           total iterations : 10
#           final cost : 7.70e-01
#           time : 1.33e+00 [sec]
#       final cost : 0.82
#       individual costs : 0.72, 0.92, 0.80
#     MPSE.gd():
#         initial stress : 8.17e-01
#         fixed : None
#         batch size : 50
#       gd.multiple():
#         computation parameters:
#           stochastic : True
#           constraint : True
#           projected : [False, True]
#           scheme : ['mm', 'mm']
#           initial lr : 1.00e+02, 1.00e+01
#           max_iter : 10
#           max_step : 1.00e+10
#         progress:
#           iter:      cost:     grad:     lr:       step:
#             10/  10  7.06e-01  1.72e-01  1.65e+01  4.08e-01
#         results:
#           conclusion : maximum number of iterations reached
#           total iterations : 10
#           final cost : 7.06e-01
#           time : 8.52e-01 [sec]
#       final cost : 0.76
#       individual costs : 0.71, 0.82, 0.74
#     MPSE.gd():
#         initial stress : 7.55e-01
#         fixed : None
#       gd.multiple():
#         computation parameters:
#           stochastic : False
#           constraint : True
#           projected : [False, True]
#           scheme : ['bb', 'bb']
#           initial lr : 1.00e+02, 1.00e+01
#           max_iter : 100
#           max_step : 1.00e+10
#         progress:
#           iter:      cost:     grad:     lr:       step:
#            100/ 100  3.37e-01  4.43e-02  3.59e+01  7.93e-03
#         results:
#           conclusion : maximum number of iterations reached
#           total iterations : 100
#           final cost : 3.37e-01
#           time : 1.00e+01 [sec]
#       final cost : 0.34
#       individual costs : 0.28, 0.35, 0.37

# %% [markdown]
# Here is the florence example:

# %%
mview.mpse_tsne('florence', perplexity=20,
               show_plots=True, verbose=2)
# Out:
#   mview.MPSE():
#     data details:
#       number of perspectives : 2
#       number of samples : 46
#     visualization details:
#       embedding dimension : 3
#       image dimension : 2
#       visualization type : tsne
#   setup visualization instance for perspective 1 :
#       mview.TSNE():
#         data details:
#           number of samples : 46
#         embedding details:
#           embedding dimension : 2
#           perplexity : 20.00
#         TSNE.initialize():
#           method : random
#           initial cost : 1.37e+00
#   setup visualization instance for perspective 2 :
#       mview.TSNE():
#         data details:
#           number of samples : 46
#         embedding details:
#           embedding dimension : 2
#           perplexity : 20.00
#         TSNE.initialize():
#           method : random
#           initial cost : 1.51e+00
#     initialize:
#       fixed embedding : False
#       initial embedding : random
#       fixed projections : False
#       initial projections : random
#     MPSE.gd():
#         initial stress : 1.37e+00
#         mpse method : fixed projections
#       gd.single():
#         computation parameters:
#           stochastic : False
#           constraint : False
#           scheme : bb
#           initial lr : 1.00e+02
#           max_iter : 10
#           max_step : 1.00e+10
#         progress:
#           iter:      cost:     grad:     lr:       step:
#             10/  10  9.15e-01  3.70e-03  2.98e+01  2.47e-02
#         results:
#           conclusion : maximum number of iterations reached
#           total iterations : 10
#           final cost : 9.15e-01
#           final gradient size : 3.70e-03
#           final learning rate : 2.98e+01
#           final step size : 2.47e-02
#           time : 1.66e-02 [sec]
#       final cost : 0.86
#       individual costs : 0.85, 0.86
#     MPSE.gd():
#         initial stress : 8.58e-01
#         fixed : None
#       gd.multiple():
#         computation parameters:
#           stochastic : False
#           constraint : True
#           projected : [False, True]
#           scheme : ['mm', 'mm']
#           initial lr : 1.00e+02, 1.00e+01
#           max_iter : 10
#           max_step : 1.00e+10
#         progress:
#           iter:      cost:     grad:     lr:       step:
#             10/  10  7.51e-01  7.77e-02  1.38e+01  7.48e-02
#         results:
#           conclusion : maximum number of iterations reached
#           total iterations : 10
#           final cost : 7.51e-01
#           time : 2.23e-02 [sec]
#       final cost : 0.72
#       individual costs : 0.77, 0.67
#     MPSE.gd():
#         initial stress : 7.21e-01
#         fixed : None
#         batch size : 23
#       gd.multiple():
#         computation parameters:
#           stochastic : True
#           constraint : True
#           projected : [False, True]
#           scheme : ['mm', 'mm']
#           initial lr : 1.00e+02, 1.00e+01
#           max_iter : 10
#           max_step : 1.00e+10
#         progress:
#           iter:      cost:     grad:     lr:       step:
#             10/  10  5.90e-01  1.73e-01  1.08e+01  1.30e-01
#         results:
#           conclusion : maximum number of iterations reached
#           total iterations : 10
#           final cost : 5.90e-01
#           time : 3.13e-02 [sec]
#       final cost : 0.72
#       individual costs : 0.88, 0.51
#     MPSE.gd():
#         initial stress : 7.18e-01
#         fixed : None
#       gd.multiple():
#         computation parameters:
#           stochastic : False
#           constraint : True
#           projected : [False, True]
#           scheme : ['bb', 'bb']
#           initial lr : 1.00e+02, 1.00e+01
#           max_iter : 100
#           max_step : 1.00e+10
#         progress:
#           iter:      cost:     grad:     lr:       step:
#            100/ 100  4.97e-01  1.23e-02  3.40e-01  4.08e-03
#         results:
#           conclusion : maximum number of iterations reached
#           total iterations : 100
#           final cost : 4.97e-01
#           time : 1.82e-01 [sec]
#       final cost : 0.50
#       individual costs : 0.61, 0.34

# %% [markdown]
# Here is the basic disk examples having multiple perspectives:

# %%
mview.mpse_tsne('disk', n_samples=500, n_perspectives=5,
                perplexity=300, 
                show_plots=True, verbose=2)
# Out:
#   mview.MPSE():
#     data details:
#       number of perspectives : 5
#       number of samples : 500
#     visualization details:
#       embedding dimension : 3
#       image dimension : 2
#       visualization type : tsne
#   setup visualization instance for perspective 1 :
#       mview.TSNE():
#         data details:
#           number of samples : 500
#         embedding details:
#           embedding dimension : 2
#           perplexity : 300.00
#         TSNE.initialize():
#           method : random
#           initial cost : 1.09e+00
#   setup visualization instance for perspective 2 :
#       mview.TSNE():
#         data details:
#           number of samples : 500
#         embedding details:
#           embedding dimension : 2
#           perplexity : 300.00
#         TSNE.initialize():
#           method : random
#           initial cost : 1.09e+00
#   setup visualization instance for perspective 3 :
#       mview.TSNE():
#         data details:
#           number of samples : 500
#         embedding details:
#           embedding dimension : 2
#           perplexity : 300.00
#         TSNE.initialize():
#           method : random
#           initial cost : 1.08e+00
#   setup visualization instance for perspective 4 :
#       mview.TSNE():
#         data details:
#           number of samples : 500
#         embedding details:
#           embedding dimension : 2
#           perplexity : 300.00
#         TSNE.initialize():
#           method : random
#           initial cost : 1.08e+00
#   setup visualization instance for perspective 5 :
#       mview.TSNE():
#         data details:
#           number of samples : 500
#         embedding details:
#           embedding dimension : 2
#           perplexity : 300.00
#         TSNE.initialize():
#           method : random
#           initial cost : 1.08e+00
#     initialize:
#       fixed embedding : False
#       initial embedding : random
#       fixed projections : False
#       initial projections : random
#     MPSE.gd():
#         initial stress : 1.05e+00
#         mpse method : fixed projections
#       gd.single():
#         computation parameters:
#           stochastic : False
#           constraint : False
#           scheme : bb
#           initial lr : 1.00e+02
#           max_iter : 10
#           max_step : 1.00e+10
#         progress:
#           iter:      cost:     grad:     lr:       step:
#             10/  10  7.29e-01  4.59e-04  1.60e+02  4.56e-02
#         results:
#           conclusion : maximum number of iterations reached
#           total iterations : 10
#           final cost : 7.29e-01
#           final gradient size : 4.59e-04
#           final learning rate : 1.60e+02
#           final step size : 4.56e-02
#           time : 2.63e-01 [sec]
#       final cost : 0.68
#       individual costs : 0.52, 0.62, 0.69, 0.88, 0.66
#     MPSE.gd():
#         initial stress : 6.84e-01
#         fixed : None
#         batch size : 100
#       gd.multiple():
#         computation parameters:
#           stochastic : True
#           constraint : True
#           projected : [False, True]
#           scheme : ['mm', 'mm']
#           initial lr : 1.00e+02, 1.00e+01
#           max_iter : 10
#           max_step : 1.00e+10
#         progress:
#           iter:      cost:     grad:     lr:       step:
#             10/  10  3.39e-01  1.23e-01  1.34e+02  3.61e-01
#         results:
#           conclusion : maximum number of iterations reached
#           total iterations : 10
#           final cost : 3.39e-01
#           time : 1.12e+00 [sec]
#       final cost : 0.30
#       individual costs : 0.22, 0.28, 0.35, 0.34, 0.30
#     MPSE.gd():
#         initial stress : 2.99e-01
#         fixed : None
#         batch size : 50
#       gd.multiple():
#         computation parameters:
#           stochastic : True
#           constraint : True
#           projected : [False, True]
#           scheme : ['mm', 'mm']
#           initial lr : 1.00e+02, 1.00e+01
#           max_iter : 10
#           max_step : 1.00e+10
#         progress:
#           iter:      cost:     grad:     lr:       step:
#             10/  10  1.69e-01  1.20e-01  1.67e+01  1.43e-01
#         results:
#           conclusion : maximum number of iterations reached
#           total iterations : 10
#           final cost : 1.69e-01
#           time : 7.19e-01 [sec]
#       final cost : 0.21
#       individual costs : 0.18, 0.21, 0.23, 0.23, 0.21
#     MPSE.gd():
#         initial stress : 2.13e-01
#         fixed : None
#       gd.multiple():
#         computation parameters:
#           stochastic : False
#           constraint : True
#           projected : [False, True]
#           scheme : ['bb', 'bb']
#           initial lr : 1.00e+02, 1.00e+01
#           max_iter : 100
#           max_step : 1.00e+10
#         progress:
#           iter:      cost:     grad:     lr:       step:
#            100/ 100  8.85e-02  5.05e-03  8.87e+00  2.64e-02
#         results:
#           conclusion : maximum number of iterations reached
#           total iterations : 100
#           final cost : 8.85e-02
#           time : 5.96e+00 [sec]
#       final cost : 0.09
#       individual costs : 0.09, 0.09, 0.09, 0.09, 0.09

# %% [markdown]
# Here is the phishing data example

# %%
mview.mpse_tsne('phishing',
                perplexity=30, 
                show_plots=True, verbose=2)
# Out:
#   mview.MPSE():
#     data details:
#       number of perspectives : 4
#       number of samples : 100
#     visualization details:
#       embedding dimension : 3
#       image dimension : 2
#       visualization type : tsne
#   setup visualization instance for perspective Address_bar_based :
#       mview.TSNE():
#         data details:
#           number of samples : 100
#         embedding details:
#           embedding dimension : 2
#           perplexity : 30.00
#         TSNE.initialize():
#           method : random
#           initial cost : 2.38e+00
#   setup visualization instance for perspective Abnormal_based :
#       mview.TSNE():
#         data details:
#           number of samples : 100
#         embedding details:
#           embedding dimension : 2
#           perplexity : 30.00
#         TSNE.initialize():
#           method : random
#           initial cost : 2.45e+00
#   setup visualization instance for perspective HTML_and_JavaScript_based :
#       mview.TSNE():
#         data details:
#           number of samples : 100
#         embedding details:
#           embedding dimension : 2
#           perplexity : 30.00
#         TSNE.initialize():
#           method : random
#           initial cost : 1.24e+00
#   setup visualization instance for perspective Domain_based :
#       mview.TSNE():
#         data details:
#           number of samples : 100
#         embedding details:
#           embedding dimension : 2
#           perplexity : 30.00
#         TSNE.initialize():
#           method : random
#           initial cost : 2.45e+00
#     initialize:
#       fixed embedding : False
#       initial embedding : random
#       fixed projections : False
#       initial projections : random
#     MPSE.gd():
#         initial stress : 2.17e+00
#         mpse method : fixed projections
#       gd.single():
#         computation parameters:
#           stochastic : False
#           constraint : False
#           scheme : bb
#           initial lr : 1.00e+02
#           max_iter : 10
#           max_step : 1.00e+10
#         progress:
#           iter:      cost:     grad:     lr:       step:
#             10/  10  1.80e+00  2.49e-03  3.72e+01  3.81e-02
#         results:
#           conclusion : maximum number of iterations reached
#           total iterations : 10
#           final cost : 1.80e+00
#           final gradient size : 2.49e-03
#           final learning rate : 3.72e+01
#           final step size : 3.81e-02
#           time : 3.49e-02 [sec]
#       final cost : 1.74
#       individual costs : 2.13, 1.76, 1.08, 1.82
#     MPSE.gd():
#         initial stress : 1.74e+00
#         fixed : None
#       gd.multiple():
#         computation parameters:
#           stochastic : False
#           constraint : True
#           projected : [False, True]
#           scheme : ['mm', 'mm']
#           initial lr : 1.00e+02, 1.00e+01
#           max_iter : 10
#           max_step : 1.00e+10
#         progress:
#           iter:      cost:     grad:     lr:       step:
#             10/  10  1.45e+00  1.65e-01  2.50e+01  2.41e-01
#         results:
#           conclusion : maximum number of iterations reached
#           total iterations : 10
#           final cost : 1.45e+00
#           time : 5.34e-02 [sec]
#       final cost : 1.43
#       individual costs : 1.85, 1.21, 0.82, 1.61
#     MPSE.gd():
#         initial stress : 1.43e+00
#         fixed : None
#         batch size : 50
#       gd.multiple():
#         computation parameters:
#           stochastic : True
#           constraint : True
#           projected : [False, True]
#           scheme : ['mm', 'mm']
#           initial lr : 1.00e+02, 1.00e+01
#           max_iter : 10
#           max_step : 1.00e+10
#         progress:
#           iter:      cost:     grad:     lr:       step:
#             10/  10  1.40e+00  1.85e-01  1.05e+01  2.52e-01
#         results:
#           conclusion : maximum number of iterations reached
#           total iterations : 10
#           final cost : 1.40e+00
#           time : 1.20e-01 [sec]
#       final cost : 1.41
#       individual costs : 1.81, 1.14, 0.73, 1.70
#     MPSE.gd():
#         initial stress : 1.41e+00
#         fixed : None
#       gd.multiple():
#         computation parameters:
#           stochastic : False
#           constraint : True
#           projected : [False, True]
#           scheme : ['bb', 'bb']
#           initial lr : 1.00e+02, 1.00e+01
#           max_iter : 100
#           max_step : 1.00e+10
#         progress:
#           iter:      cost:     grad:     lr:       step:
#            100/ 100  1.22e+00  9.29e-02  1.44e-01  3.46e-03
#         results:
#           conclusion : maximum number of iterations reached
#           total iterations : 100
#           final cost : 1.22e+00
#           time : 6.17e-01 [sec]
#       final cost : 1.22
#       individual costs : 1.68, 0.71, 0.49, 1.55
